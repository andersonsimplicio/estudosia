# %%
import pandas as pd

# %%
df = pd.read_csv('database/diabetes.csv')

# %%
df
# Out:
#        Unnamed: 0  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0               0          7.0          103.0                    87.0
# 1               1          0.0          151.0                    84.0
# 2               2          8.0          170.0                    78.0
# 3               3          9.0          104.0                    61.0
# 4               4          0.0          105.0                    66.0
# ...           ...          ...            ...                     ...
# 13564       13564          0.0           97.0                    56.0
# 13565       13565          1.0           78.0                    62.0
# 13566       13566          0.0           70.0                    82.0
# 13567       13567          1.0          171.0                    84.0
# 13568       13568          1.0           93.0                    79.0
#
#        TricepsThickness  SerumInsulin        BMI  DiabetesPedigree   Age  \
# ...
